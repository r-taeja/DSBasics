# %% [markdown]
# #Pandas
#
# Pandas is a python module that makes data science easy and effective.
#
# **Weather dataset**
#
# Questions:
# 1. What was the maximum temperature in New York in the month of January?
# 2. On which days did it rain?
# 3. What was the average speed of the wind during the month?

# %% [markdown]
# First, we will see in Python code.

# %%
import pandas as pd

df = pd.read_csv('nyc_weather.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ea6b4804006b> in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('nyc_weather.csv')
#       4 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#Question 1 Solution
df['Temperature'].max()

# %%
#Question 2 Solution
df['EST'][df['Events'] == "Rain"]

# %%
#Question 3 Solution
df['WindSpeedMPH'].mean()

# %% [markdown]
# #1. Introduction to Pandas DataFrame
#
# Dataframe is the main object in Pandas. It is used to represent data with rows and columns.
#
# Dataframe is a data structure representing the data in a tabular or excel spreadsheet like form.

# %% [markdown]
# **Creating a dataframe**

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4ce6f73cbb9a> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("weather_data.csv")
#       3 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#list of data

weather_data = [('1/1/2017', 32, 6, 'Rain'),
                ('1/2/2017', 35, 7, 'Sunny'),
                ('1/3/2017', 28, 2, 'Snow'),
                ('1/4/2017', 24, 7, 'Snow'),
                ('1/5/2017', 32, 4, 'Rain'),
                ('1/6/2017', 31, 2, 'Sunny')
                ]

df = pd.DataFrame(weather_data, columns = ['day', 'Temperature', 'windspeed', 'event'])

# %%
df
# Out:
#         day  Temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#Get dimensions of the table

df.shape      #total number of rows and columns
# Out:
# (6, 4)

# %%
#To view initial few (default is 5) rows, use head()
df.head()
# Out:
#         day  Temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
#To view last few (default is 5) rows, use tail()
df.tail()
# Out:
#         day  Temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#slicing
df[2:5]
# Out:
#         day  Temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
#print columns
df.columns
# Out:
# Index(['day', 'Temperature', 'windspeed', 'event'], dtype='object')

# %%
#print particular column data
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
#another way of accessing columns
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day', 'event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
#get all temperatures
df['Temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: Temperature, dtype: int64

# %%
#Get max temperature
df['Temperature'].max()
# Out:
# 35

# %%
#Get min temperature
df['Temperature'].min()
# Out:
# 24

# %%
#Print details about temperature
df["Temperature"].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: Temperature, dtype: float64

# %%
#Select which row has max temperature
df[df['Temperature'] == df['Temperature'].max()]
# Out:
#         day  Temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
#Select only day column which has maximum temperature
df['day'][df['Temperature'] == df['Temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %% [markdown]
# #Read and write CSV and XLS files

# %%
import pandas as pd
df
# Out:
#         day  Temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#INSTALL : pip3 install xlrd

#Read Excel file
df = pd.read_excel('weather_data.xlsx')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-28792610ba83> in <cell line: 0>()
#       2
#       3 #Read Excel file
# ----> 4 df = pd.read_excel('weather_data.xlsx')
#       5 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
#write data to csv
df.to_csv('weater_data.csv')
df.to_csv('noIndex_weather_data.csv')

# %%
#INSTALL : pip3 install openpyxl

#Write data to excel
df.to_excel('new.xlsx', sheet_name = 'weather_data')

# %% [markdown]
# #GROUP BY

# %%
import pandas as pd
df = pd.read_csv('weather_data_cities.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-5123ff7df98e> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('weather_data_cities.csv')
#       3 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
g = df.groupby('city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-72434f128105> in <cell line: 0>()
# ----> 1 g = df.groupby('city')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-fd3704052164> in <cell line: 0>()
# ----> 1 for city, city_df in g:
#       2     print(city)
#       3     print(city_df)
#
# NameError: name 'g' is not defined

# %%
#or to get specific group
g.get_group('new york')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e4902bf3475b> in <cell line: 0>()
#       1 #or to get specific group
# ----> 2 g.get_group('new york')
#
# NameError: name 'g' is not defined

# %%
#Find maximum temperature in each of the cities
print(g.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-aaca338450ad> in <cell line: 0>()
#       1 #Find maximum temperature in each of the cities
# ----> 2 print(g.max())
#
# NameError: name 'g' is not defined

# %%
print(g.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-355203eee933> in <cell line: 0>()
# ----> 1 print(g.mean())
#
# NameError: name 'g' is not defined

# %%
print(g.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-c888939b4952> in <cell line: 0>()
# ----> 1 print(g.describe())
#
# NameError: name 'g' is not defined

# %% [markdown]
# #Concatenate Data frames

# %%
import pandas as pd
india_weather = pd.DataFrame({
    "City" : ['Mumbai', 'Delhi', 'Bangalore'],
    "Temperature" : [32, 35, 40],
    "Humidity" : [80, 60, 70]
})

india_weather
# Out:
#         City  Temperature  Humidity
# 0     Mumbai           32        80
# 1      Delhi           35        60
# 2  Bangalore           40        70

# %%
us_weather = pd.DataFrame({
    "City" : ['New York', 'Chicago', 'Orlando'],
    "Temperature" : [21, 14, 35],
    "Humidity" : [60, 65, 75]
})

us_weather
# Out:
#        City  Temperature  Humidity
# 0  New York           21        60
# 1   Chicago           14        65
# 2   Orlando           35        75

# %%
#Concatenate two dataframes
df = pd.concat([india_weather, us_weather])
df
# Out:
#         City  Temperature  Humidity
# 0     Mumbai           32        80
# 1      Delhi           35        60
# 2  Bangalore           40        70
# 0   New York           21        60
# 1    Chicago           14        65
# 2    Orlando           35        75

# %%
#Concatenate two dataframes without duplicate indices
df = pd.concat([india_weather, us_weather], ignore_index = True)
df
# Out:
#         City  Temperature  Humidity
# 0     Mumbai           32        80
# 1      Delhi           35        60
# 2  Bangalore           40        70
# 3   New York           21        60
# 4    Chicago           14        65
# 5    Orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], axis = 1)
df
# Out:
#         City  Temperature  Humidity      City  Temperature  Humidity
# 0     Mumbai           32        80  New York           21        60
# 1      Delhi           35        60   Chicago           14        65
# 2  Bangalore           40        70   Orlando           35        75

# %% [markdown]
# #Merge Data Frames

# %%
temperature_df = pd.DataFrame({
    'City' : ["Mumbai", "Delhi", "Bengaluru", "Hyderabad"],
    "Temperature" : [32, 45, 30, 40]})

temperature_df
# Out:
#         City  Temperature
# 0     Mumbai           32
# 1      Delhi           45
# 2  Bengaluru           30
# 3  Hyderabad           40

# %%
humidity_df = pd.DataFrame({
    'City' : ["Delhi", "Mumbai", "Bengaluru"],
    "Humidity" : [68, 65, 75]})

humidity_df
# Out:
#         City  Humidity
# 0      Delhi        68
# 1     Mumbai        65
# 2  Bengaluru        75

# %%
#Merge two dataframes without explicitly mentioning index
df = pd.merge(temperature_df, humidity_df, on = 'City')
df
# Out:
#         City  Temperature  Humidity
# 0     Mumbai           32        65
# 1      Delhi           45        68
# 2  Bengaluru           30        75

# %%
#OUTER-JOIN
df = pd.merge(temperature_df, humidity_df, on = 'City', how = 'outer')
df
# Out:
#         City  Temperature  Humidity
# 0  Bengaluru           30      75.0
# 1      Delhi           45      68.0
# 2  Hyderabad           40       NaN
# 3     Mumbai           32      65.0

# %% [markdown]
# #Numerical Indexing (.loc vs iloc)

# %%
df = pd.DataFrame([1,2,3,4,5,6,7,8,9,19], index = [49,48,47,46,45,1,2,3,4,5])
df
# Out:
#      0
# 49   1
# 48   2
# 47   3
# 46   4
# 45   5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   19

# %%
#indexing by given index value
df.loc[48]
# Out:
# 0    2
# Name: 48, dtype: int64

# %%
#indexing by row number
df.iloc[1]
# Out:
# 0    2
# Name: 48, dtype: int64

# %%
df.loc[45]
# Out:
# 0    5
# Name: 45, dtype: int64

# %%
df.iloc[45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-55867d6731c3> in <cell line: 0>()
# ----> 1 df.iloc[45]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1750
#    1751             # validate the location
# -> 1752             self._validate_integer(key, axis)
#    1753
#    1754             return self.obj._ixs(key, axis=axis)
#
# ...

# %%
#Slicicng till 2nd index number
df.loc[:2]
# Out:
#     0
# 49  1
# 48  2
# 47  3
# 46  4
# 45  5
# 1   6
# 2   7

# %%
#Slicicng till 2nd row number
df.iloc[:2]
# Out:
#     0
# 49  1
# 48  2
